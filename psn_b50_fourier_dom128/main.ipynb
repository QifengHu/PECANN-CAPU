# %%
import torch

from config import Config
from core import Trainer
from utils import _torch_device, _ensure_dirs

def main():
    torch.set_default_dtype(torch.float64)
    cfg = Config()
    print("Using device:", _torch_device())
    _ensure_dirs(cfg)
    trainer = Trainer(cfg)
    trainer.run()


if __name__ == "__main__":
    main()
# Out:
# Using device: cpu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 16>()
#      13     trainer.run()
#      16 if __name__ == "__main__":
# ---> 17     main()
#
# Input In [2], in main()
#       9 cfg = Config()
#      10 print("Using device:", _torch_device())
# ---> 11 _ensure_dirs(cfg)
#      12 trainer = Trainer(cfg)
#      13 trainer.run()
#
# File ~\AppData\Roaming\MobaXterm\home\capu\3_template_psn_b50_batch128_fourier\utils\io.py:20, in _ensure_dirs(cfg)
#      18 def _ensure_dirs(cfg):
#      19     os.makedirs(cfg.out_dir, exist_ok=True)
# ---> 20     os.makedirs(cfg.model_dir, exist_ok=True)
#
# AttributeError: 'Config' object has no attribute 'model_dir'
