# %%
import torch

from config import Config
from core import Trainer
from utils import _torch_device, _ensure_dirs

def main():
    torch.set_default_dtype(torch.float64)
    cfg = Config()
    print("Using device:", _torch_device())
    _ensure_dirs(cfg)
    trainer = Trainer(cfg)
    trainer.run()


if __name__ == "__main__":
    main()
# Out:
# Using device: cpu
# Spatial1DNet(
#   (net): Sequential(
#     (0): FourierFeatureLayer()
#     (1): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Tanh()
#       )
#     )
#     (2): Linear(in_features=100, out_features=1, bias=True)
#   )
# )
# Total params: 10253
# current trial: 1
# epoch 1000 | loss 1.182e+02 | obj 1.142e+02 | constraints = 1.420e-02:   2%|▏      | 994/40000 [00:18<14:11, 45.83it/s]rela. l2 norm = 1.108e-01, linf norm = 1.216e-01
# epoch 2000 | loss 4.820e+01 | obj 4.820e+01 | constraints = 1.971e-05:   5%|▎     | 1993/40000 [00:37<12:13, 51.84it/s]rela. l2 norm = 1.065e-02, linf norm = 1.413e-02
# epoch 3000 | loss 2.463e+01 | obj 2.462e+01 | constraints = 8.741e-06:   7%|▍     | 2993/40000 [00:55<11:33, 53.38it/s]rela. l2 norm = 2.832e-03, linf norm = 5.711e-03
# epoch 4000 | loss 2.943e+01 | obj 2.943e+01 | constraints = 1.278e-05:  10%|▌     | 3990/40000 [01:12<09:29, 63.19it/s]rela. l2 norm = 3.695e-03, linf norm = 5.501e-03
# epoch 5000 | loss 3.694e+01 | obj 3.694e+01 | constraints = 5.152e-06:  12%|▋     | 4994/40000 [01:31<10:18, 56.60it/s]rela. l2 norm = 5.627e-03, linf norm = 9.250e-03
# epoch 6000 | loss 4.288e+01 | obj 4.288e+01 | constraints = 1.440e-06:  15%|▉     | 5999/40000 [01:50<10:01, 56.56it/s]rela. l2 norm = 4.798e-03, linf norm = 7.655e-03
# epoch 7000 | loss 4.624e+01 | obj 4.624e+01 | constraints = 1.708e-07:  17%|█     | 6996/40000 [02:08<10:21, 53.08it/s]rela. l2 norm = 7.974e-03, linf norm = 1.123e-02
# epoch 8000 | loss 3.102e+01 | obj 3.102e+01 | constraints = 6.036e-06:  20%|█▏    | 7998/40000 [02:27<10:59, 48.54it/s]rela. l2 norm = 3.516e-03, linf norm = 5.925e-03
# epoch 9000 | loss 9.393e+00 | obj 9.392e+00 | constraints = 4.258e-06:  22%|█▎    | 8998/40000 [02:47<10:39, 48.50it/s]rela. l2 norm = 3.012e-03, linf norm = 3.487e-03
# epoch 10000 | loss 1.376e+01 | obj 1.376e+01 | constraints = 6.296e-06:  25%|█▏   | 9997/40000 [03:06<09:20, 53.54it/s]rela. l2 norm = 3.469e-03, linf norm = 5.554e-03
# epoch 11000 | loss 3.054e+01 | obj 3.054e+01 | constraints = 3.886e-06:  27%|█   | 10994/40000 [03:23<07:32, 64.03it/s]rela. l2 norm = 4.418e-03, linf norm = 6.438e-03
# epoch 12000 | loss 7.442e+00 | obj 7.442e+00 | constraints = 1.464e-06:  30%|█▏  | 11997/40000 [03:41<09:51, 47.32it/s]rela. l2 norm = 1.832e-03, linf norm = 3.488e-03
# epoch 13000 | loss 6.146e+00 | obj 6.146e+00 | constraints = 9.614e-07:  32%|█▎  | 12997/40000 [03:59<06:43, 66.94it/s]rela. l2 norm = 1.259e-03, linf norm = 2.112e-03
# epoch 14000 | loss 6.039e+00 | obj 6.039e+00 | constraints = 9.964e-07:  35%|█▍  | 13998/40000 [04:18<08:37, 50.20it/s]rela. l2 norm = 2.037e-03, linf norm = 2.448e-03
# epoch 15000 | loss 7.174e+00 | obj 7.173e+00 | constraints = 1.238e-06:  37%|█▍  | 14998/40000 [04:36<06:47, 61.41it/s]rela. l2 norm = 1.149e-03, linf norm = 1.740e-03
# epoch 16000 | loss 5.552e+00 | obj 5.552e+00 | constraints = 4.028e-07:  40%|█▌  | 15996/40000 [04:54<07:10, 55.75it/s]rela. l2 norm = 1.320e-03, linf norm = 1.996e-03
# epoch 17000 | loss 5.050e+00 | obj 5.050e+00 | constraints = 4.578e-07:  42%|█▋  | 16994/40000 [05:13<07:28, 51.30it/s]rela. l2 norm = 1.243e-03, linf norm = 2.419e-03
# epoch 18000 | loss 4.141e+00 | obj 4.140e+00 | constraints = 1.230e-06:  45%|█▊  | 17995/40000 [05:31<06:23, 57.44it/s]rela. l2 norm = 1.040e-03, linf norm = 2.247e-03
# epoch 19000 | loss 3.477e+00 | obj 3.477e+00 | constraints = 5.380e-07:  47%|█▉  | 18993/40000 [05:48<06:52, 50.91it/s]rela. l2 norm = 1.835e-03, linf norm = 2.531e-03
# epoch 20000 | loss 1.871e+00 | obj 1.871e+00 | constraints = 1.225e-07:  50%|█▉  | 19994/40000 [06:06<05:46, 57.78it/s]rela. l2 norm = 1.462e-03, linf norm = 1.976e-03
# epoch 21000 | loss 3.099e+00 | obj 3.099e+00 | constraints = 8.826e-07:  52%|██  | 20995/40000 [06:22<04:16, 74.18it/s]rela. l2 norm = 1.392e-03, linf norm = 2.634e-03
# epoch 22000 | loss 1.251e+00 | obj 1.250e+00 | constraints = 8.989e-07:  55%|██▏ | 21990/40000 [06:37<05:26, 55.09it/s]rela. l2 norm = 8.960e-04, linf norm = 1.704e-03
# epoch 23000 | loss 1.175e+00 | obj 1.175e+00 | constraints = 1.849e-07:  57%|██▎ | 22996/40000 [06:56<04:54, 57.66it/s]rela. l2 norm = 8.918e-04, linf norm = 1.386e-03
# epoch 24000 | loss 1.284e+00 | obj 1.284e+00 | constraints = 1.458e-06:  60%|██▍ | 23995/40000 [07:13<05:42, 46.74it/s]rela. l2 norm = 7.008e-04, linf norm = 1.476e-03
# epoch 25000 | loss 1.579e+00 | obj 1.579e+00 | constraints = 3.515e-07:  62%|██▍ | 24990/40000 [07:30<04:06, 60.86it/s]rela. l2 norm = 1.067e-03, linf norm = 1.625e-03
# epoch 26000 | loss 1.372e+00 | obj 1.372e+00 | constraints = 1.565e-07:  65%|██▌ | 25996/40000 [07:47<03:59, 58.59it/s]rela. l2 norm = 7.000e-04, linf norm = 1.241e-03
# epoch 27000 | loss 8.423e-01 | obj 8.422e-01 | constraints = 1.317e-07:  67%|██▋ | 26990/40000 [08:05<03:46, 57.51it/s]rela. l2 norm = 5.558e-04, linf norm = 1.111e-03
# epoch 28000 | loss 8.556e-01 | obj 8.556e-01 | constraints = 2.929e-08:  70%|██▊ | 27996/40000 [08:23<03:30, 56.97it/s]rela. l2 norm = 8.758e-04, linf norm = 1.455e-03
# epoch 29000 | loss 4.991e-01 | obj 4.991e-01 | constraints = 4.133e-09:  72%|██▉ | 28998/40000 [08:42<03:17, 55.76it/s]rela. l2 norm = 6.057e-04, linf norm = 7.995e-04
# epoch 30000 | loss 6.645e-01 | obj 6.643e-01 | constraints = 3.146e-07:  75%|██▉ | 29999/40000 [08:59<02:50, 58.54it/s]rela. l2 norm = 7.810e-04, linf norm = 1.386e-03
# epoch 31000 | loss 7.745e-01 | obj 7.745e-01 | constraints = 2.980e-08:  77%|███ | 30996/40000 [09:18<03:22, 44.52it/s]rela. l2 norm = 5.413e-04, linf norm = 9.059e-04
# epoch 32000 | loss 4.601e-01 | obj 4.601e-01 | constraints = 4.576e-08:  80%|███▏| 31993/40000 [09:34<02:32, 52.36it/s]rela. l2 norm = 4.190e-04, linf norm = 6.711e-04
# epoch 33000 | loss 3.276e-01 | obj 3.275e-01 | constraints = 7.045e-08:  82%|███▎| 32997/40000 [09:52<02:16, 51.18it/s]rela. l2 norm = 5.468e-04, linf norm = 8.122e-04
# epoch 34000 | loss 4.370e-01 | obj 4.370e-01 | constraints = 4.689e-08:  85%|███▍| 33994/40000 [10:11<01:47, 56.12it/s]rela. l2 norm = 2.823e-04, linf norm = 5.011e-04
# epoch 35000 | loss 2.479e-01 | obj 2.479e-01 | constraints = 1.468e-07:  87%|███▍| 34994/40000 [10:29<01:52, 44.51it/s]rela. l2 norm = 5.469e-04, linf norm = 1.003e-03
# epoch 36000 | loss 2.691e-01 | obj 2.691e-01 | constraints = 1.998e-08:  90%|███▌| 35990/40000 [10:46<01:03, 63.55it/s]rela. l2 norm = 3.695e-04, linf norm = 5.433e-04
# epoch 37000 | loss 2.883e-01 | obj 2.883e-01 | constraints = 1.367e-08:  92%|███▋| 36997/40000 [11:04<01:00, 49.56it/s]rela. l2 norm = 4.077e-04, linf norm = 7.159e-04
# epoch 38000 | loss 2.443e-01 | obj 2.443e-01 | constraints = 1.212e-08:  95%|███▊| 37993/40000 [11:23<00:39, 50.25it/s]rela. l2 norm = 2.882e-04, linf norm = 4.008e-04
# epoch 39000 | loss 2.456e-01 | obj 2.456e-01 | constraints = 2.946e-09:  97%|███▉| 38997/40000 [11:41<00:16, 60.31it/s]rela. l2 norm = 7.755e-04, linf norm = 1.284e-03
# epoch 40000 | loss 2.167e-01 | obj 2.166e-01 | constraints = 3.989e-08: 100%|███▉| 39995/40000 [12:00<00:00, 52.28it/s]rela. l2 norm = 4.226e-04, linf norm = 6.154e-04
# epoch 40000 | loss 2.167e-01 | obj 2.166e-01 | constraints = 3.989e-08: 100%|████| 40000/40000 [12:00<00:00, 55.54it/s]
# [viz] Saved pic/psn_freq_b50_batch_128_fourier_nn2_100_1_losses.png
# [viz] Saved pic/psn_freq_b50_batch_128_fourier_nn2_100_1_lambda_mu.png
# [viz] Saved pic/psn_freq_b50_batch_128_fourier_nn2_100_1_l2_linf.png
# [viz] Saved pic/psn_freq_b50_batch_128_fourier_nn2_100_1_x_u_upred.png
# mean rel L_2: 4.226e-04
# std  rel L_2: 0.000e+00
# ********************
# mean L_inf: 6.154e-04
# std  L_inf: 0.000e+00
# ********************
